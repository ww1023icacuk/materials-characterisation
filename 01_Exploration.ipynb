# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv("/Users/wendy/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Year 2/MATE50001/Computing/Coursework/dataset_1 (1).csv")
df1.head()
df1.info()
df1.describe()
df1["label"].value_counts()


df2 = pd.read_csv("/Users/wendy/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Year 2/MATE50001/Computing/Coursework/dataset_2 (1).csv")
df2.head()
df2.info()
df2.describe()
df2["label"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   density                  4957 non-null   float64
#  1   vacancy_content          4948 non-null   float64
#  2   melting_temperature      4940 non-null   float64
#  3   heat_conductivity        4951 non-null   float64
#  4   band_gap                 4955 non-null   float64
#  5   crystallinity_index      4947 non-null   float64
#  6   thermal_expansion_coeff  4945 non-null   float64
#  7   young_modulus            4956 non-null   float64
#  8   hardness                 4947 non-null   float64
#  9   lattice_parameter        4954 non-null   float64
#  10  label                    5000 non-null   object
# dtypes: float64(10), object(1)
# memory usage: 429.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# ...

# %%
df1.isna().sum()
df2.isna().sum()
# Out:
# feature_1    5
# feature_2    5
# feature_3    3
# feature_4    5
# feature_5    2
# feature_6    4
# feature_7    3
# feature_8    5
# label        0
# dtype: int64

# %%
df1.hist(figsize=(15, 10))
plt.show()
